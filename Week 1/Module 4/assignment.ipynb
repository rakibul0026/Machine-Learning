# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %% [markdown]
# # Question 1
#
# Load the Titanic dataset and display:
#
# ●  Dataset shape
#
# ●  First 10 rows
#
# ●  5 random samples

# %%
#Load and display
df=pd.read_csv('titanic_data_updated.csv')
df
# Out:
#      PassengerId Survived  Pclass  \
# 0              1       no   third
# 1              2      yes   first
# 2              3      yes   third
# 3              4      yes   first
# 4              5       no   third
# ..           ...      ...     ...
# 886          887       no  second
# 887          888      yes   first
# 888          889       no   third
# 889          890      yes   first
# 890          891       no   third
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#Dataset shape 
print("Shape :",df.shape)
# Out:
# Shape : (891, 12)

# %%
#First 10 rows 
print("First 10 rows:")
df.head(10)
# Out:
# First 10 rows:
#    PassengerId Survived  Pclass  \
# 0            1       no   third
# 1            2      yes   first
# 2            3      yes   third
# 3            4      yes   first
# 4            5       no   third
# 5            6       no   third
# 6            7       no   first
# 7            8       no   third
# 8            9      yes   third
# 9           10      yes  second
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
# 5 random samples
print("5 random samples:")
df.sample(5)
# Out:
# 5 random samples:
#      PassengerId Survived  Pclass                                   Name  \
# 411          412       no   third                        Hart, Mr. Henry
# 794          795       no   third                  Dantcheff, Mr. Ristiu
# 312          313       no  second  Lahtinen, Mrs. William (Anna Sylfven)
# 586          587       no  second                Jarvis, Mr. John Denzil
# 303          304      yes  second                    Keane, Miss. Nora A
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 411    male   NaN      0      0  394140   6.8583   NaN        Q
# 794    male  25.0      0      0  349203   7.8958   NaN        S
# 312  female  26.0      1      1  250651  26.0000   NaN        S
# 586    male  47.0      0      0  237565  15.0000   NaN        S
# 303  female   NaN      0      0  226593  12.3500  E101        Q

# %% [markdown]
# # Question 2 (10 Marks)
#
# Perform feature screening on the Titanic dataset by:
#
# ●  Finding total missing values
#
# ●  Finding duplicate rows
#
# ●  Removing duplicate rows permanently

# %%
#Finding total missing values 
print("Total missing values:")
df.isnull().sum()
# Out:
# Total missing values:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Finding duplicate rows 
print("Duplicate rows ",df.duplicated().sum())
# Out:
# Duplicate rows  0

# %%
#Removing duplicate rows permanently
df.drop_duplicates(inplace=True)

# %% [markdown]
# # Question 3 (10 Marks)
#
# Perform statistical profiling of the Titanic dataset and display:
#
# ●  Dataset information
#
# ●  Statistical summary of numerical columns
#
# Also write 2 observations from the output.

# %%
 #Dataset information 
print("Dataset information :")
df.info()
# Out:
# Dataset information :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB

# %%
#Statistical summary of numerical columns
print("Statistical summary of numerical columns:")
df.describe()
# Out:
# Statistical summary of numerical columns:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594   32.204208
# std     257.353842   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000   38.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# Also write 2 observations from the output
#
# observations:
#
# 1st->Most passenger were around 30 years old
#
# 2nd->some passenger paid very high fares compared to other

# %% [markdown]
# # Question 4 (10 Marks)
# Perform univariate categorical analysis on the Survived column by:
#
# ●  Creating a countplot
#
# ●  Calculating percentage distribution
#
# ●  Creating a pie chart
#
# Write 2 insights from the analysis

# %%
#Creating  a countplot
sns.countplot(x='Survived',data=df)
plt.title("Countplot of Survived")
plt.show()

# %%
#Calculating percentage distribution 
Survived_percent=df['Survived'].value_counts(normalize=True)*100
print(Survived_percent)
# Out:
# Survived
# no     61.616162
# yes    38.383838
# Name: proportion, dtype: float64

# %%
#Creating a pie chart 
plt.pie(x=df['Survived'].value_counts(), 
        autopct='%1.1f%%',
        labels=['Not Survived','Survived'])
plt.title("Survival Percentage")
plt.show()

# %% [markdown]
# Write 2 insights from the analysis
#
# insights:
#
# 1.Most passengers did not survive
#
# 2.The survival percentage is lower than the non survival percentage

# %% [markdown]
# # Question 5 (10 Marks)
#
# Perform univariate numerical analysis on the Age column by:
#
# ●  Creating a histogram
#
# ●  Creating a KDE plot
#
# Write 2 observations from the plots.

# %%
# Creating a histogram 
plt.hist(df['Age'],bins=20,edgecolor='Black')
plt.title("Age Histogram")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
#Creating a KDE plot 
sns.kdeplot(df['Age'].dropna(),fill=True)
plt.title("Age Kde plot")
plt.show()

# %% [markdown]
# Write 2 observations from the plots.
#
# observations
#
# 1.Most passengers were between 20 and 40 years old
#
# 2.This graph shows a small spike in children aged 0-5 ,that means there are also several children passengers on the ship

# %% [markdown]
# # Question 6 (10 Marks)
#
# Perform multivariate analysis between Sex and Survived using a countplot with hue.
#
# Also calculate normalized survival ratios using groupby().
#
# Write 2 insights from the analysis.

# %%
plt.figure(figsize=(7,5))
sns.countplot(x='Sex',hue='Survived',data=df)
plt.title("Sex Vs Survived")
plt.show()

# %%
#calculate normalized survival ratios using groupby()
survival_ratio=df.groupby('Sex')['Survived'].value_counts(normalize=True)
print(survival_ratio)
# Out:
# Sex     Survived
# female  yes         0.742038
#         no          0.257962
# male    no          0.811092
#         yes         0.188908
# Name: proportion, dtype: float64

# %% [markdown]
# Insights
#
# 1.Female passengers had a higher survival rate
#
# 2.Male passengers had a lower servival ratio compared to females

# %% [markdown]
# # Question 7 (10 Marks)
#
# Create a barplot showing the relationship between Pclass and Fare.
#
# Write 2 observations from the visualization.

# %%
sns.barplot(x='Pclass',y='Fare',data=df)
plt.title("Pclass and Fare")
plt.show()

# %% [markdown]
# observations
#
# 1.First class passenger paid the highest fare
#
# 2.Third class passengers paid the lowest fare

# %% [markdown]
# # Question 8 (10 Marks)
#
# Create a KDE plot to compare the Age distribution of survived and non-survived passengers.
#
# Write 2 insights from the graph.

# %%
sns.kdeplot(df[df['Survived']==1]['Age'].dropna(),shade=True,label='Survived',color='green')
sns.kdeplot(df[df['Survived']==0]['Age'].dropna(),shade=True,label='NotSurvived',color='red')
plt.title("Age distribution of survived and non-survived passengers")
plt.xlabel('Age')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9964\2301108857.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df['Survived']==1]['Age'].dropna(),shade=True,label='Survived',color='green')
# C:\Users\user\AppData\Local\Temp\ipykernel_9964\2301108857.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df['Survived']==0]['Age'].dropna(),shade=True,label='NotSurvived',color='red')
# C:\Users\user\AppData\Local\Temp\ipykernel_9964\2301108857.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sns.kdeplot(data=df,x=df['Age'],hue=df['Survived'])
plt.show()

# %% [markdown]
# insights
#
# 1.Younger passengers had a better survival rate.
#
# 2.Non-survived passengers were more spread across different age groups.

# %% [markdown]
# # Question 9 (10 Marks)
#
# Perform feature engineering and train-test split by:
#
# ●  Dropping PassengerId, Name, and Ticket columns
#
# ●  Separating features (X) and target (y)
#
# ●  Splitting the dataset using test_size=0.2 and random_state=42
#
# Display the shapes of train and test datasets.

# %%
#Dropping PassengerId, Name, and Ticket columns 
df.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)

# %%
#Separating features (X) and target (y) 
x=df.drop('Survived',axis=1)
y=df['Survived']

# %%
#Splitting the dataset using test_size=0.2 and random_state=42 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2 ,random_state=42)

# %%
#Display the shapes of train and test datasets.
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)
# Out:
# x_train shape: (712, 8)
# x_test shape: (179, 8)
# y_train shape: (712,)
# y_test shape: (179,)

# %% [markdown]
# # Question 10 (10 Marks)
#
# Handle missing values in the Titanic dataset by:
#
# ●  Imputing missing Age values using SimpleImputer with mean strategy
#
# ●  Imputing missing Embarked values using most frequent strategy
#
# ●  Imputing missing Cabin values using constant strategy with "Missing"
# Finally, check whether any missing values remain.

# %%
#Imputing missing Age values using SimpleImputer with mean strategy 
age_imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
age_imputer.fit(x_train[['Age']])
x_train['Age']=age_imputer.transform(x_train[['Age']]).ravel()
x_test['Age']=age_imputer.transform(x_test[['Age']]).ravel()

#Imputing missing Embarked values using most frequent strategy 
embarked_imputer=SimpleImputer(missing_values=np.nan,strategy='most_frequent')
embarked_imputer.fit(x_train[['Embarked']])
x_train['Embarked']=embarked_imputer.transform(x_train[['Embarked']]).ravel()
x_test['Embarked']=embarked_imputer.transform(x_test[['Embarked']]).ravel()

#Imputing missing Cabin values using constant strategy with "Missing" 
cabin_imputer=SimpleImputer(missing_values=np.nan,strategy='constant',fill_value='Missing')
cabin_imputer.fit(x_train[['Cabin']])
x_train['Cabin']=cabin_imputer.transform(x_train[['Cabin']]).ravel()
x_test['Cabin']=cabin_imputer.transform(x_test[['Cabin']]).ravel()

#check whether any missing values remain
print("Missing values in x_train:\n",x_train.isnull().sum())
print("Missing values in x_test:\n",x_test.isnull().sum())
# Out:
# Missing values in x_train:
#  Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64
# Missing values in x_test:
#  Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64
